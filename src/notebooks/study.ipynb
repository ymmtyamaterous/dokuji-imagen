# %%
import sys
sys.path.append('..')

# from script.phase02.step01 import Value
# from script.phase02.step02 import Value
# from script.phase02.step03 import Value
from script.phase02.step04 import Value

# %%
# step 1
x = Value(3)
print(x)
# Out:
# Value(data=3, grad=0.0)

# %%
# step 2
a = Value(2)
b = Value(3)
c = a + b
print(c)
# Out:
# Value(data=5, grad=0.0)

# %%
# step 3
a = Value(2)
b = Value(3)
c = a * b
print(c)
# Out:
# Value(data=6, grad=0.0)

# %%
# step 4
a = Value(2)
b = Value(3)
c = a * b
print(c._prev)
# Out:
# {Value(data=2, grad=0.0), Value(data=3, grad=0.0)}

# %%
# 計算グラフの理解確認
x = Value(2)
y = Value(3)
z = x + y
w = z * y
w
# Out:
# Value(data=15, grad=0.0)
